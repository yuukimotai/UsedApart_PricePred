# %% [markdown]
# # 多項式関数
# 多項式関数は、最も基本的な関数です。

# %% [markdown]
# ### 多項式とは？

# %% [markdown]
# 例えば以下のような、複数の項からなる式を**多項式**といいます。
# $$2x-1$$
# $$3x^2+2x+1$$
# $$4x^3+2x^2+x+3$$
#
# このような式を用いた関数を**多項式関数**といいます。
# $$y=2x-1$$
# $$y=3x^2+2x+1$$
# $$y=4x^3+2x^2+x+3$$
#
# 一般化すると、多項式は次のように表すことができます。
# $$y = a_nx^n+a_{n-1}x^{n-1}+\cdots+a_1x+ a_0$$
# このような多項式を、**n次の多項式**といいます。

# %% [markdown]
# ### 多項式を実装
# 数式$y=3x^2+2x+1$をコードで実装します。

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_func(x):  
    return 3*x**2 + 2*x + 1  # 3x^2 + 2x + 1

x = np.linspace(-5, 5)
y = my_func(x)  # y = f(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# 数式$y=4x^3+2x^2+x+3$をコードで実装します。

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_func(x):  
    return 4*x**3 + 2*x**2 + x + 3  # 4x^3 + 2x^2 + x + 3

x = np.linspace(-5, 5)
y = my_func(x)  # y = f(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 演習:
# 以下のコードを補完し、数式$y=3x^3 - 2x^2 + x + 1$をコードで実装しましょう。

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_func(x):  
    return 3*x**3 - 2*x**2 + x + 1

x = np.linspace(-5, 5)
y = my_func(x)  # y = f(x)

plt.plot(x, y)
plt.show()
